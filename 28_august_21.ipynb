# %%
import pandas as pd

# %%
df=pd.DataFrame({"name":["Harry","Ron","Hermoinie","malfoy","snape","Dumbledore"],"character":["student","student","student","student","master","headmaster"]})
df
# Out:
#          name   character
# 0       Harry     student
# 1         Ron     student
# 2   Hermoinie     student
# 3      malfoy     student
# 4       snape      master
# 5  Dumbledore  headmaster

# %%
df.head()
# Out:
#         name character
# 0      Harry   student
# 1        Ron   student
# 2  Hermoinie   student
# 3     malfoy   student
# 4      snape    master

# %%
df.tail()
# Out:
#          name   character
# 1         Ron     student
# 2   Hermoinie     student
# 3      malfoy     student
# 4       snape      master
# 5  Dumbledore  headmaster

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       6 non-null      object
#  1   character  6 non-null      object
# dtypes: object(2)
# memory usage: 224.0+ bytes

# %%
df.describe()
# Out:
#          name character
# count       6         6
# unique      6         3
# top     Harry   student
# freq        1         4

# %%
df=pd.read_csv("C:\\Users\\vidya\\Desktop\\Dataset.csv")

# %%
df
# Out:
#     patient_barcode tissue_source_site patient_id gender  height  weight
# 0      TCGA-2H-A9GF                 2H       A9GF   MALE   183.0    95.0
# 1      TCGA-2H-A9GG                 2H       A9GG   MALE   178.0    74.0
# 2      TCGA-2H-A9GH                 2H       A9GH   MALE   183.0    91.0
# 3      TCGA-2H-A9GI                 2H       A9GI   MALE   188.0   100.0
# 4      TCGA-2H-A9GJ                 2H       A9GJ   MALE   189.0    70.0
# ..              ...                ...        ...    ...     ...     ...
# 195    TCGA-Z6-A8JD                 Z6       A8JD   MALE   172.0    69.0
# 196    TCGA-Z6-A8JE                 Z6       A8JE   MALE   168.0    61.0
# 197    TCGA-Z6-A9VB                 Z6       A9VB   MALE   159.0    62.0
# 198    TCGA-Z6-AAPN                 Z6       AAPN   MALE   165.0    74.0
# 199    TCGA-ZR-A9CJ                 ZR       A9CJ   MALE     NaN     NaN
#
# [200 rows x 6 columns]

# %%
df.head()
# Out:
#   patient_barcode tissue_source_site patient_id gender  height  weight
# 0    TCGA-2H-A9GF                 2H       A9GF   MALE   183.0    95.0
# 1    TCGA-2H-A9GG                 2H       A9GG   MALE   178.0    74.0
# 2    TCGA-2H-A9GH                 2H       A9GH   MALE   183.0    91.0
# 3    TCGA-2H-A9GI                 2H       A9GI   MALE   188.0   100.0
# 4    TCGA-2H-A9GJ                 2H       A9GJ   MALE   189.0    70.0

# %%
df.tail()
# Out:
#     patient_barcode tissue_source_site patient_id gender  height  weight
# 195    TCGA-Z6-A8JD                 Z6       A8JD   MALE   172.0    69.0
# 196    TCGA-Z6-A8JE                 Z6       A8JE   MALE   168.0    61.0
# 197    TCGA-Z6-A9VB                 Z6       A9VB   MALE   159.0    62.0
# 198    TCGA-Z6-AAPN                 Z6       AAPN   MALE   165.0    74.0
# 199    TCGA-ZR-A9CJ                 ZR       A9CJ   MALE     NaN     NaN

# %%
df.tissue_source_site
# Out:
# 0      2H
# 1      2H
# 2      2H
# 3      2H
# 4      2H
#        ..
# 195    Z6
# 196    Z6
# 197    Z6
# 198    Z6
# 199    ZR
# Name: tissue_source_site, Length: 200, dtype: object

# %%
df.iloc[:5,:3]
# Out:
#   patient_barcode tissue_source_site patient_id
# 0    TCGA-2H-A9GF                 2H       A9GF
# 1    TCGA-2H-A9GG                 2H       A9GG
# 2    TCGA-2H-A9GH                 2H       A9GH
# 3    TCGA-2H-A9GI                 2H       A9GI
# 4    TCGA-2H-A9GJ                 2H       A9GJ

# %%
df.weight.mean()
# Out:
# 75.64646464646465

# %%
df.isnull()
# Out:
#      patient_barcode  tissue_source_site  patient_id  gender  height  weight
# 0              False               False       False   False   False   False
# 1              False               False       False   False   False   False
# 2              False               False       False   False   False   False
# 3              False               False       False   False   False   False
# 4              False               False       False   False   False   False
# ..               ...                 ...         ...     ...     ...     ...
# 195            False               False       False   False   False   False
# 196            False               False       False   False   False   False
# 197            False               False       False   False   False   False
# 198            False               False       False   False   False   False
# 199            False               False       False   False    True    True
#
# [200 rows x 6 columns]

# %%
df.loc[:4,['patient_barcode','patient_id']]
# Out:
#   patient_barcode patient_id
# 0    TCGA-2H-A9GF       A9GF
# 1    TCGA-2H-A9GG       A9GG
# 2    TCGA-2H-A9GH       A9GH
# 3    TCGA-2H-A9GI       A9GI
# 4    TCGA-2H-A9GJ       A9GJ

# %%
df.isnull().sum()
# Out:
# patient_barcode        0
# tissue_source_site     0
# patient_id             0
# gender                 0
# height                11
# weight                 2
# dtype: int64

# %%
df.weight=df.weight.fillna(df.weight.mean())

# %%
df.weight
# Out:
# 0       95.000000
# 1       74.000000
# 2       91.000000
# 3      100.000000
# 4       70.000000
#           ...
# 195     69.000000
# 196     61.000000
# 197     62.000000
# 198     74.000000
# 199     75.646465
# Name: weight, Length: 200, dtype: float64

# %%
df.dropna(inplace=True)

# %%
v=pd.Series([4,2,5,-1],index=['a','b','c','d'])
v
# Out:
# a    4
# b    2
# c    5
# d   -1
# dtype: int64

# %%
v['c']
# Out:
# 5

# %%
df[1:]
# Out:
#          name   character
# 1         Ron     student
# 2   Hermoinie     student
# 3      malfoy     student
# 4       snape      master
# 5  Dumbledore  headmaster

# %%
data = {'Country': ['Belgium',  'India',  'Brazil'],'Capital': ['Brussels',  'New Delhi',  'Brasilia'],'Population': [1, 1303171035, 207847528]}
df = pd.DataFrame(data,columns=['Country',  'Capital',  'Population'])

# %%
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels           1
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasilia   207847528

# %%
 df[df['Population']>1200000000]
# Out:
#   Country    Capital  Population
# 1   India  New Delhi  1303171035

# %%
df.sort_index()
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasilia   207847528

# %%
df.sort_values(by='Capital')
# Out:
#    Country    Capital  Population
# 2   Brazil   Brasilia   207847528
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035

# %%
 df.rank()
# Out:
#    Country  Capital  Population
# 0      1.0      2.0         1.0
# 1      3.0      3.0         3.0
# 2      2.0      1.0         2.0

# %%
df.shape
# Out:
# (3, 3)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['Country', 'Capital', 'Population'], dtype='object')

# %%
 df.count()
# Out:
# Country       3
# Capital       3
# Population    3
# dtype: int64

# %%
 df.cumsum()
# Out:
#               Country                    Capital  Population
# 0             Belgium                   Brussels    11190846
# 1        BelgiumIndia          BrusselsNew Delhi  1314361881
# 2  BelgiumIndiaBrazil  BrusselsNew DelhiBrasilia  1522209409

# %%
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi  1303171035
# 2   Brazil   Brasilia   207847528

# %%
df.min()
# Out:
# Country        Belgium
# Capital       Brasilia
# Population    11190846
# dtype: object

# %%
df.max()
# Out:
# Country            India
# Capital        New Delhi
# Population    1303171035
# dtype: object

# %%
df.median()
# Out:
# C:\Users\vidya\AppData\Local\Temp/ipykernel_2112/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Population    207847528.0
# dtype: float64

# %%
df.mean()
# Out:
# C:\Users\vidya\AppData\Local\Temp/ipykernel_2112/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Population    5.074031e+08
# dtype: float64

# %%
f = lambda a:a*2 #keyw,boundvar,body

# %%
df.apply(f,axis=1)#can specify axis(0-column,1-row)
# Out:
#           Country             Capital  Population
# 0  BelgiumBelgium    BrusselsBrussels           2
# 1      IndiaIndia  New DelhiNew Delhi  2606342070
# 2    BrazilBrazil    BrasiliaBrasilia   415695056

# %%
df.applymap(lambda a: a+a)
# Out:
#           Country             Capital  Population
# 0  BelgiumBelgium    BrusselsBrussels           2
# 1      IndiaIndia  New DelhiNew Delhi  2606342070
# 2    BrazilBrazil    BrasiliaBrasilia   415695056

# %%
vv = pd.Series([7, -2, 3],  index=['a',  'c',  'd'])

# %%
v
# Out:
# a    4
# b    2
# c    5
# d   -1
# dtype: int64

# %%
v+ vv
# Out:
# a    11.0
# b     NaN
# c     3.0
# d     2.0
# dtype: float64

# %%
v.add(vv, fill_value=0)
# Out:
# a    11.0
# b     2.0
# c     3.0
# d     2.0
# dtype: float64

# %%
v.sub(vv, fill_value=2)#doubt d
# Out:
# a   -3.0
# b    0.0
# c    7.0
# d   -4.0
# dtype: float64

# %%
df=pd.read_csv("C:\\Users\\vidya\\Downloads\\supermarket_sales - Sheet1.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal     NaN
# 2    631-41-3108      A     Yangon        Normal     NaN
# 3    123-19-1176      A     Yangon        Member     NaN
# 4    373-73-7910      A     Yangon        Normal     NaN
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.Date=df.Date.fillna("dd-mm-yy")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal     NaN
# 2    631-41-3108      A     Yangon        Normal     NaN
# 3    123-19-1176      A     Yangon        Member     NaN
# 4    373-73-7910      A     Yangon        Normal     NaN
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.isnull()
# Out:
#      Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0         False   False  False          False   False         False
# 1         False   False  False          False    True         False
# 2         False   False  False          False    True         False
# 3         False   False  False          False    True         False
# 4         False   False  False          False    True         False
# ..          ...     ...    ...            ...     ...           ...
# 995       False   False  False          False   False         False
# 996       False   False  False          False   False         False
# 997       False   False  False          False   False         False
# 998       False   False  False          False   False         False
# 999       False   False  False          False   False         False
#
#      Unit price  Quantity  Tax 5%  Total   Date   Time  Payment   cogs  \
# 0         False     False   False  False  False  False    False  False
# ...

# %%
df.Gender=df.Gender.fillna("no gender")
df
# Out:
#       Invoice ID Branch       City Customer type     Gender  \
# 0    750-67-8428      A     Yangon        Member     Female
# 1    226-31-3081      C  Naypyitaw        Normal  no gender
# 2    631-41-3108      A     Yangon        Normal  no gender
# 3    123-19-1176      A     Yangon        Member  no gender
# 4    373-73-7910      A     Yangon        Normal  no gender
# ..           ...    ...        ...           ...        ...
# 995  233-67-5758      C  Naypyitaw        Normal       Male
# 996  303-96-2227      B   Mandalay        Normal     Female
# 997  727-02-1313      A     Yangon        Member       Male
# 998  347-56-2442      A     Yangon        Normal       Male
# 999  849-09-3807      A     Yangon        Member     Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
print("+++++++++++++")
# Out:
# +++++++++++++

# %%
import pandas as pd

# %%
from sklearn.impute import CategericalImputer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-66f81d9baa2d> in <module>()
# ----> 1 from sklearn.impute import CategericalImputer
#
# ImportError: cannot import name 'CategericalImputer' from 'sklearn.impute' (/usr/local/lib/python3.7/dist-packages/sklearn/impute/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\vidya\\Downloads\\supermarket_sales - Sheet1.csv")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal     NaN
# 2    631-41-3108      A     Yangon        Normal     NaN
# 3    123-19-1176      A     Yangon        Member     NaN
# 4    373-73-7910      A     Yangon        Normal     NaN
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
v=['Date']

# %%
imputer = SimpleImputer(missing_values=np.nan,strategy='most_frequent')
df[v]=imputer.fit_transform(df[v])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e054305f40e1> in <module>()
# ----> 1 imputer = SimpleImputer(missing_values=np.nan,strategy='most_frequent')
#       2 df[v]=imputer.fit_transform(df[v])
#
# NameError: name 'SimpleImputer' is not defined

# %%
df.head()
